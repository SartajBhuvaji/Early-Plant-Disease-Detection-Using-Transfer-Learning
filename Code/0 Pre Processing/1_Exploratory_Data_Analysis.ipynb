# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ls
# Out:
# gdrive	sample_data

# %%
# %cd '/content/gdrive/MyDrive/Master/Fall 22/DS Project/DataSet'
# !ls
# Out:
# /content/gdrive/MyDrive/Master/Fall 22/DS Project/DataSet
# kaggle.json  PlantVillage_1  PlantVillage_2

# %%
# !pip install basic_image_eda
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2
plt.style.use('seaborn-whitegrid')
import seaborn as sns
sns.set_theme(style="whitegrid")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: basic_image_eda in /usr/local/lib/python3.7/dist-packages (0.0.3)

# %%
df = pd.read_csv('/content/metadata.csv')

# %%
df.head()
# Out:
#   Type  No                   PlantVillage  Count
# 0   D1   1  Pepper__bell___Bacterial_spot    997
# 1   D1   2         Pepper__bell___healthy   1478
# 2   D1   3          Potato___Early_blight   1000
# 3   D1   4           Potato___Late_blight   1000
# 4   D1   5               Potato___healthy    152

# %%
count_df = df.sort_values(by='Count', ascending =False) 
plt.figure(figsize=(20,20))
sns.barplot(x="Count", y="PlantVillage", data= count_df)
plt.plot()
# Out:
# []

# %% [markdown]
# From above graph we can see that there are lots of classes that have 1000 images in them.

# %%
plt.figure(figsize=(10, 15)) 
plt.barh(df['PlantVillage'], df['Count'], height = 5)
plt.show()

# %%
by_ds = df.groupby(['Type'])['Count'].sum()
by_ds.plot(kind='bar', style ='seaborn-whitegrid')
#plt.style.use('seaborn-whitegrid')
plt.show()

# %%
img = cv2.imread("/content/gdrive/MyDrive/Master/Fall 22/DS Project/DataSet/PlantVillage_1/Pepper__bell___Bacterial_spot/0022d6b7-d47c-4ee2-ae9a-392a53f48647___JR_B.Spot 8964.JPG")
plt.imshow(img)

# %%
print(img.shape)
print(img.size)
print(img.dtype)
gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
print(gray.shape)
plt.imshow(gray)
# Out:
# (256, 256, 3)
# 196608
# uint8
# (256, 256)

# %%
d1 = '/content/gdrive/MyDrive/Master/Fall 22/DS Project/Untitled folder/PlantVillage_1'
d2 = '/content/gdrive/MyDrive/Master/Fall 22/DS Project/Untitled folder/plantvillage dataset_2'

# %%
BasicImageEDA.explore(d1)
# Out:
# found 156 images.
# Using 2 threads. (max:2)
# 100%|██████████| 156/156 [00:49<00:00,  3.14it/s]
# *--------------------------------------------------------------------------------------*
# number of images                         |  156
#
# dtype                                    |  uint8
# channels                                 |  [3, 4]
# extensions                               |  ['jpeg', 'jpg', 'png']
#
# min height                               |  256
# max height                               |  256
# mean height                              |  256.0
# median height                            |  256
#
# min width                                |  256
# max width                                |  256
# mean width                               |  256.0
# median width                             |  256
#
# mean height/width ratio                  |  1.0
# median height/width ratio                |  1.0
# recommended input size(by mean)          |  [256 256] (h x w, multiples of 8)
# recommended input size(by mean)          |  [256 256] (h x w, multiples of 16)
# recommended input size(by mean)          |  [256 256] (h x w, multiples of 32)
#
# channel mean(0~1)                        |  [0.11507356 0.14951585 0.09043389]
# channel std(0~1)                         |  [0.18435784 0.22445726 0.15165535]
# *--------------------------------------------------------------------------------------*
# eda ended in 00 hours 01 minutes 05 seconds
# {'dtype': 'uint8',
#  'channels': [3, 4],
#  'extensions': ['jpeg', 'jpg', 'png'],
#  'min_h': 256,
#  'max_h': 256,
#  'mean_h': 256.0,
#  'median_h': 256,
#  'min_w': 256,
#  'max_w': 256,
#  'mean_w': 256.0,
#  'median_w': 256,
#  'mean_hw_ratio': 1.0,
#  'median_hw_ratio': 1.0,
#  'rec_hw_size_8': array([256, 256]),
#  'rec_hw_size_16': array([256, 256]),
#  'rec_hw_size_32': array([256, 256]),
#  'mean': array([0.11507356, 0.14951585, 0.09043389], dtype=float32),
#  'std': array([0.18435784, 0.22445726, 0.15165535], dtype=float32)}

# %%
BasicImageEDA.explore(d2)
# Out:
# found 1501 images.
# Using 2 threads. (max:2)
# 100%|██████████| 1501/1501 [07:58<00:00,  3.13it/s]
# *--------------------------------------------------------------------------------------*
# number of images                         |  1501
#
# dtype                                    |  uint8
# channels                                 |  [3, 4]
# extensions                               |  ['jpeg', 'jpg', 'png']
#
# min height                               |  256
# max height                               |  256
# mean height                              |  256.0
# median height                            |  256
#
# min width                                |  256
# max width                                |  256
# mean width                               |  256.0
# median width                             |  256
#
# mean height/width ratio                  |  1.0
# median height/width ratio                |  1.0
# recommended input size(by mean)          |  [256 256] (h x w, multiples of 8)
# recommended input size(by mean)          |  [256 256] (h x w, multiples of 16)
# recommended input size(by mean)          |  [256 256] (h x w, multiples of 32)
#
# channel mean(0~1)                        |  [0.45975956 0.5704413  0.42566407]
# channel std(0~1)                         |  [0.21601745 0.2234647  0.22212927]
# *--------------------------------------------------------------------------------------*
# eda ended in 00 hours 08 minutes 28 seconds
# {'dtype': 'uint8',
#  'channels': [3, 4],
#  'extensions': ['jpeg', 'jpg', 'png'],
#  'min_h': 256,
#  'max_h': 256,
#  'mean_h': 256.0,
#  'median_h': 256,
#  'min_w': 256,
#  'max_w': 256,
#  'mean_w': 256.0,
#  'median_w': 256,
#  'mean_hw_ratio': 1.0,
#  'median_hw_ratio': 1.0,
#  'rec_hw_size_8': array([256, 256]),
#  'rec_hw_size_16': array([256, 256]),
#  'rec_hw_size_32': array([256, 256]),
#  'mean': array([0.45975956, 0.5704413 , 0.42566407], dtype=float32),
#  'std': array([0.21601745, 0.2234647 , 0.22212927], dtype=float32)}

# %%
#plt.barh(df['PlantVillage 1'], df['Count'])
plt.figure(figsize=(10, 30)) 
#plt.figure(figsize=(20, 3))  # width:20, height:3
plt.barh(df['PlantVillage 1'], df['Count'], height = 2)
# Out:
# <BarContainer object of 53 artists>

# %%
df[df['Count']==df['Count'].max()]
# Out:
#    Type  No                            PlantVillage 1  Count
# 30   D2  31  Orange___Haunglongbing_(Citrus_greening)   5507

# %%
df[df['Count']==df['Count'].min()]
# Out:
#    Type  No    PlantVillage 1  Count
# 4    D1   5  Potato___healthy    152
# 37   D2  38  Potato___healthy    152

# %%
df.head()
# Out:
#   Type  No                 PlantVillage 1  Count
# 0   D1   1  Pepper__bell___Bacterial_spot    997
# 1   D1   2         Pepper__bell___healthy   1478
# 2   D1   3          Potato___Early_blight   1000
# 3   D1   4           Potato___Late_blight   1000
# 4   D1   5               Potato___healthy    152

# %%
# Out:
#   Type  No                   PlantVillage  Count
# 0   D1   1  Pepper__bell___Bacterial_spot    997
# 1   D1   2         Pepper__bell___healthy   1478
# 2   D1   3          Potato___Early_blight   1000
# 3   D1   4           Potato___Late_blight   1000
# 4   D1   5               Potato___healthy    152

# %%
plt.plot(df.No, df.Count)
